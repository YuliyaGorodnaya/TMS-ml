# %%
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard

tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1) # настройка логгирования

# %%
model.fit(x_train, y_train, epochs=10, callbacks=[tensorboard_callback]) # добавляем callback при обучении модели

# %% [markdown]
# tensorboard --logdir=./logs # запуск из командной строки
# http://localhost:6006 - интерактивная панель в браузере
