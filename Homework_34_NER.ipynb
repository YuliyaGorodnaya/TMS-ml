# %%
# !pip -q install pandas beautifulsoup4 lxml requests spacy tqdm
# !python -m spacy download ru_core_news_sm -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 84.0 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
URL = "https://ir.yandex.ru/financial-releases?year=2025&report=q3"

# %%
html = requests.get(URL, headers={"User-Agent":"Mozilla/5.0"}).text
soup = BeautifulSoup(html, "lxml")

# %%
tables = pd.read_html(html, header=None, decimal=",", thousands=" ")
# Out:
# /tmp/ipython-input-3699163378.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html, header=None, decimal=",", thousands=" ")

# %%
def score_table(df: pd.DataFrame) -> int:
    text = " ".join(map(str, df.head(10).values.flatten())).lower()
    keys = ["выручка", "скорректирован", "ebitda", "рентабельность", "чистая прибыль", "девять месяцев", "три месяца"]
    return sum(k in text for k in keys)

scored = [(i, score_table(tables[i])) for i in range(len(tables))]
scored_sorted = sorted(scored, key=lambda x: x[1], reverse=True)
scored_sorted[:10]
# Out:
# [(0, 7),
#  (1, 6),
#  (2, 6),
#  (5, 6),
#  (4, 5),
#  (6, 5),
#  (7, 5),
#  (8, 5),
#  (14, 4),
#  (3, 3)]

# %%
best_idx = scored_sorted[0][0]
df_raw = tables[best_idx].copy()
df_raw.head(20)
# Out:
#                             0  \
# 0                 В млрд руб.
# 1                         NaN
# 2   Результаты Группы Яндекса
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6      Поисковые сервисы и ИИ
# 7                         NaN
# 8                         NaN
# 9           Городские сервисы
# 10                        NaN
# 11                        NaN
# 12       Персональные сервисы
# 13                        NaN
# 14                        NaN
# 15                    Б2Б Тех
# 16                        NaN
# 17                        NaN
# 18      Автономные технологии
# 19                        NaN
#
#                                                     1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                             Выручка
# 3                 Скорректированный показатель EBITDA
# 4   Рентабельность скорректированного показателя E...
# 5                    Скорректированная чистая прибыль
# 6                                             Выручка
# 7                 Скорректированный показатель EBITDA
# 8   Рентабельность скорректированного показателя E...
# 9                                             Выручка
# 10                Скорректированный показатель EBITDA
# 11  Рентабельность скорректированного показателя E...
# 12                                            Выручка
# 13                Скорректированный показатель EBITDA
# 14  Рентабельность скорректированного показателя E...
# 15                                            Выручка
# 16                Скорректированный показатель EBITDA
# 17  Рентабельность скорректированного показателя E...
# 18                                            Выручка
# 19                Скорректированный показатель EBITDA
#
#                                         2  \
# 0   Три месяца, закончившиеся 30 сентября
# 1                                    2025
# 2                                   366.1
# 3                                    78.1
# 4                                   21,3%
# 5                                    44.7
# 6                                   138.5
# 7                                    63.0
# 8                                   45,5%
# 9                                   200.4
# 10                                   18.9
# 11                                   9,4%
# 12                                   54.8
# 13                                    3.4
# 14                                   6,2%
# 15                                   12.4
# 16                                    2.2
# 17                                  17,4%
# 18                                    0.2
# 19                                  (4,2)
#
#                                         3  \
# 0   Три месяца, закончившиеся 30 сентября
# 1                                    2024
# 2                                   276.8
# 3                                    54.7
# 4                                   19,8%
# 5                                    25.1
# 6                                   127.0
# 7                                    58.0
# 8                                   45,7%
# 9                                   146.9
# 10                                    4.2
# 11                                   2,9%
# 12                                   32.8
# 13                                    0.2
# 14                                   0,5%
# 15                                    8.4
# 16                                    1.0
# 17                                  12,2%
# 18                                      —
# 19                                  (2,1)
#
#                                         4  \
# 0   Три месяца, закончившиеся 30 сентября
# 1                               Изменение
# 2                                     32%
# 3                                     43%
# 4                                1,5 п.п.
# 5                                     78%
# 6                                      9%
# 7                                      9%
# 8                               -0,2 п.п.
# 9                                     36%
# 10                                   347%
# 11                               6,5 п.п.
# 12                                    67%
# 13                                 н/прим
# 14                               5,8 п.п.
# 15                                    47%
# 16                                   110%
# 17                               5,2 п.п.
# 18                                 н/прим
# 19                                   100%
#
#                                             5  \
# 0   Девять месяцев, закончившиеся 30 сентября
# 1                                        2025
# 2                                      1005.1
# 3                                       193.0
# 4                                       19,2%
# 5                                        87.9
# 6                                       388.3
# 7                                       176.3
# 8                                       45,4%
# 9                                       561.2
# 10                                       40.0
# 11                                       7,1%
# 12                                      152.0
# 13                                        4.4
# 14                                       2,9%
# 15                                       34.2
# 16                                        6.5
# 17                                      19,1%
# 18                                        0.3
# 19                                     (10,5)
#
#                                             6  \
# 0   Девять месяцев, закончившиеся 30 сентября
# 1                                        2024
# 2                                       754.4
# 3                                       139.9
# 4                                       18,5%
# 5                                        69.6
# 6                                       343.2
# 7                                       151.1
# 8                                       44,0%
# 9                                       403.6
# 10                                       15.9
# 11                                       3,9%
# 12                                       88.3
# 13                                      (3,4)
# 14                                      -3,8%
# 15                                       22.7
# 16                                        2.4
# 17                                      10,7%
# 18                                        0.1
# 19                                      (5,4)
#
#                                             7
# 0   Девять месяцев, закончившиеся 30 сентября
# 1                                   Изменение
# 2                                         33%
# 3                                         38%
# 4                                    0,7 п.п.
# 5                                         26%
# 6                                         13%
# 7                                         17%
# 8                                    1,4 п.п.
# 9                                         39%
# 10                                       152%
# 11                                   3,2 п.п.
# 12                                        72%
# 13                                     н/прим
# 14                                     н/прим
# 15                                        51%
# 16                                       169%
# 17                                   8,4 п.п.
# 18                                       308%
# 19                                        93%

# %%
def normalize_value(x):
    if pd.isna(x):
        return None

    s = str(x).strip()
    s = s.replace("\xa0", " ").replace("−", "-") # NBSP, минус
    s_low = s.lower()

    if s_low in {"—", "-", "н/прим", "n/a", "na"}:
        return None

    # (4,2) преобразует в -4,2
    is_neg = bool(re.match(r"^\(.*\)$", s))
    s = s.strip("()")

    # убирает пробелы в числах: "1 005,1" в "1005,1"
    s = re.sub(r"(?<=\d)\s+(?=\d)", "", s)

    # 21,3% в 21,3
    s = s.replace("%", "")

    # запятую в точку
    s = s.replace(",", ".")

    # оставляет только число/точку/минус
    if not re.search(r"\d", s):
        return None
    s = re.sub(r"[^0-9\.\-]", "", s)

    try:
        val = float(s)
        return -val if is_neg else val
    except:
        return None

# %%
def flatten_columns(df: pd.DataFrame) -> pd.DataFrame:
    if isinstance(df.columns, pd.MultiIndex):
        df = df.copy()
        df.columns = [
            " ".join([str(c).strip() for c in col if str(c).strip() != "nan"]).strip()
            for col in df.columns.values
        ]
    else:
        df = df.copy()
        df.columns = [str(c).strip() for c in df.columns]
    return df

df = flatten_columns(df_raw)
df.head()
# Out:
#                            0  \
# 0                В млрд руб.
# 1                        NaN
# 2  Результаты Группы Яндекса
# 3                        NaN
# 4                        NaN
#
#                                                    1  \
# 0                                                NaN
# 1                                                NaN
# 2                                            Выручка
# 3                Скорректированный показатель EBITDA
# 4  Рентабельность скорректированного показателя E...
#
#                                        2  \
# 0  Три месяца, закончившиеся 30 сентября
# 1                                   2025
# 2                                  366.1
# 3                                   78.1
# 4                                  21,3%
#
#                                        3  \
# 0  Три месяца, закончившиеся 30 сентября
# 1                                   2024
# 2                                  276.8
# 3                                   54.7
# 4                                  19,8%
#
#                                        4  \
# 0  Три месяца, закончившиеся 30 сентября
# 1                              Изменение
# 2                                    32%
# 3                                    43%
# 4                               1,5 п.п.
#
#                                            5  \
# 0  Девять месяцев, закончившиеся 30 сентября
# 1                                       2025
# 2                                     1005.1
# 3                                      193.0
# 4                                      19,2%
#
#                                            6  \
# 0  Девять месяцев, закончившиеся 30 сентября
# 1                                       2024
# 2                                      754.4
# 3                                      139.9
# 4                                      18,5%
#
#                                            7
# 0  Девять месяцев, закончившиеся 30 сентября
# 1                                  Изменение
# 2                                        33%
# 3                                        38%
# 4                                   0,7 п.п.

# %%
text_cols = [c for c in df.columns if df[c].astype(str).str.contains("Выручка|EBITDA|Рентабельность|чист", case=False, na=False).any()]

# %%
df2 = df.copy()

# %%
def is_mostly_numeric(col):
    sample = df2[col].head(30).astype(str)
    hits = sample.str.contains(r"\d", regex=True, na=False).mean()
    return hits > 0.6

non_num_cols = [c for c in df2.columns[:4] if not is_mostly_numeric(c)]
non_num_cols
# Out:
# ['0', '1']

# %%
id_cols = non_num_cols[:2] if len(non_num_cols) >= 2 else [df2.columns[0]]
value_cols = [c for c in df2.columns if c not in id_cols]

facts = df2.melt(id_vars=id_cols, value_vars=value_cols, var_name="col", value_name="value_raw")
facts["value"] = facts["value_raw"].apply(normalize_value)

facts.head(15)
# Out:
#                             0  \
# 0                 В млрд руб.
# 1                         NaN
# 2   Результаты Группы Яндекса
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6      Поисковые сервисы и ИИ
# 7                         NaN
# 8                         NaN
# 9           Городские сервисы
# 10                        NaN
# 11                        NaN
# 12       Персональные сервисы
# 13                        NaN
# 14                        NaN
#
#                                                     1 col  \
# 0                                                 NaN   2
# 1                                                 NaN   2
# 2                                             Выручка   2
# 3                 Скорректированный показатель EBITDA   2
# 4   Рентабельность скорректированного показателя E...   2
# 5                    Скорректированная чистая прибыль   2
# 6                                             Выручка   2
# 7                 Скорректированный показатель EBITDA   2
# 8   Рентабельность скорректированного показателя E...   2
# 9                                             Выручка   2
# 10                Скорректированный показатель EBITDA   2
# 11  Рентабельность скорректированного показателя E...   2
# 12                                            Выручка   2
# 13                Скорректированный показатель EBITDA   2
# 14  Рентабельность скорректированного показателя E...   2
#
#                                 value_raw   value
# 0   Три месяца, закончившиеся 30 сентября     0.3
# 1                                    2025  2025.0
# 2                                   366.1   366.1
# 3                                    78.1    78.1
# 4                                   21,3%    21.3
# 5                                    44.7    44.7
# 6                                   138.5   138.5
# 7                                    63.0    63.0
# 8                                   45,5%    45.5
# 9                                   200.4   200.4
# 10                                   18.9    18.9
# 11                                   9,4%     9.4
# 12                                   54.8    54.8
# 13                                    3.4     3.4
# 14                                   6,2%     6.2

# %%
if len(id_cols) == 2:
    facts = facts.rename(columns={id_cols[0]:"entity", id_cols[1]:"metric"})
else:
    facts = facts.rename(columns={id_cols[0]:"entity_metric"})
    facts["entity"] = facts["entity_metric"].astype(str).str.replace(r"\s{2,}", " ", regex=True).str.strip()
    facts["metric"] = None

# период и тип колонки: 2025/2024/Изменение и "3 мес / 9 мес" пробую вытащить по тексту колонки
def parse_period(col_name: str):
    s = str(col_name)
    year = re.search(r"(20\d{2})", s)
    yr = year.group(1) if year else None
    is_change = "Измен" in s or "Change" in s
    return yr, is_change

facts[["year","is_change"]] = facts["col"].apply(lambda c: pd.Series(parse_period(c)))
facts["source"] = f"table_{best_idx}"

# фильтр: только строки где есть число или процент/изменение
facts_clean = facts.dropna(subset=["value_raw"]).copy()

# выбрасываю пустые
facts_clean = facts_clean[~facts_clean["value_raw"].astype(str).str.strip().isin(["", "nan"])]

facts_clean.head(20)
# Out:
#                        entity  \
# 0                 В млрд руб.
# 1                         NaN
# 2   Результаты Группы Яндекса
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6      Поисковые сервисы и ИИ
# 7                         NaN
# 8                         NaN
# 9           Городские сервисы
# 10                        NaN
# 11                        NaN
# 12       Персональные сервисы
# 13                        NaN
# 14                        NaN
# 15                    Б2Б Тех
# 16                        NaN
# 17                        NaN
# 18      Автономные технологии
# 19                        NaN
#
#                                                metric col  \
# 0                                                 NaN   2
# 1                                                 NaN   2
# 2                                             Выручка   2
# 3                 Скорректированный показатель EBITDA   2
# 4   Рентабельность скорректированного показателя E...   2
# 5                    Скорректированная чистая прибыль   2
# 6                                             Выручка   2
# 7                 Скорректированный показатель EBITDA   2
# 8   Рентабельность скорректированного показателя E...   2
# 9                                             Выручка   2
# 10                Скорректированный показатель EBITDA   2
# 11  Рентабельность скорректированного показателя E...   2
# 12                                            Выручка   2
# 13                Скорректированный показатель EBITDA   2
# 14  Рентабельность скорректированного показателя E...   2
# 15                                            Выручка   2
# 16                Скорректированный показатель EBITDA   2
# 17  Рентабельность скорректированного показателя E...   2
# 18                                            Выручка   2
# 19                Скорректированный показатель EBITDA   2
#
#                                 value_raw   value  year  is_change   source
# 0   Три месяца, закончившиеся 30 сентября     0.3  None      False  table_0
# 1                                    2025  2025.0  None      False  table_0
# 2                                   366.1   366.1  None      False  table_0
# 3                                    78.1    78.1  None      False  table_0
# 4                                   21,3%    21.3  None      False  table_0
# 5                                    44.7    44.7  None      False  table_0
# 6                                   138.5   138.5  None      False  table_0
# 7                                    63.0    63.0  None      False  table_0
# 8                                   45,5%    45.5  None      False  table_0
# 9                                   200.4   200.4  None      False  table_0
# 10                                   18.9    18.9  None      False  table_0
# 11                                   9,4%     9.4  None      False  table_0
# 12                                   54.8    54.8  None      False  table_0
# 13                                    3.4     3.4  None      False  table_0
# 14                                   6,2%     6.2  None      False  table_0
# 15                                   12.4    12.4  None      False  table_0
# 16                                    2.2     2.2  None      False  table_0
# 17                                  17,4%    17.4  None      False  table_0
# 18                                    0.2     0.2  None      False  table_0
# 19                                  (4,2)    -4.2  None      False  table_0

# %%
import spacy
nlp = spacy.load("ru_core_news_sm")

# %%
main_text = soup.get_text("\n", strip=True)

# lines = [ln.strip() for ln in main_text.split("\n") if ln.strip()]
# bullet_lines = [ln for ln in lines if ln.startswith("•") or ln.startswith("*")]

li_texts = [li.get_text(" ", strip=True) for li in soup.select("li")]
bullet_lines = [t for t in li_texts if re.search(r"\d", t)]
bullet_lines[:10], len(bullet_lines)
# Out:
# (['Выручка за третий квартал составила 366,1 млрд рублей, увеличившись на\n                32% год к году.',
#   'Скорректированный показатель EBITDA за третий квартал составил 78,1 млрд\n                рублей или 21,3% от выручки, рост 1,5 п.п. по сравнению с аналогичным\n                периодом прошлого года.',
#   'Рекламная выручка Яндекса выросла на 11% до 116 млрд рублей за третий\n                квартал и на 15% до 325 млрд рублей за девять месяцев 2025 года по\n                отношению к аналогичным периодам 2024 года.',
#   'Подписная выручка Яндекса выросла на 48% до 23 млрд рублей за третий\n                квартал и на 49% до 65 млрд рублей за девять месяцев 2025 года по\n                отношению к аналогичным периодам 2024 года.',
#   'Яндекс до конца 2027 года запустит в российских городах 20 тысяч\n                роботов-доставщиков. Новые роботы впервые будут производиться серийно, а\n                доставка ими будет обходиться дешевле, чем курьерами.',
#   '9 сентября 2025 года акционеры компании приняли решение о выплате\n                дивидендов за первое полугодие 2025 года в размере 80 рублей на акцию.\n                Общая сумма составила около 30,4 млрд рублей. Дивиденды были выплачены\n                акционерам 3 октября 2025 года.',
#   '9 сентября 2025 года на внеочередном общем собрании акционеров МКПАО «ЯНДЕКС» было принято решение о выплате дивидендов за первое полугодие 2025 года в размере 80 рублей на одну обыкновенную акцию. Выплата д ивидендов\n                была завершена 3 октября 2025 года. Общая сумма выплат составила 30,4\n                млрд рублей.',
#   'В третьем квартале 2025 года участникам программы долгосрочной мотивации\n                Яндекса было выдано 679 тысяч акций, что составляет 0,17% от уставного\n                капитала компании. По состоянию на конец сентября 2025 года общее\n                количество голосующих акций составило 379,8 млн штук.',
#   'В рамках утвержденной советом директоров МКПАО «Я НДЕКС » программы биржевых облигаций 9 сентября был размещен второй выпуск облигаций на сумму 25 млрд рублей с ежемесячной выплатой купона с фиксированной ставкой в 13,5%.',
#   'Из категории Прочие бизнес-юниты и инициативы выделены следующие\n                сегменты: Финтех, который был переименован в Финансовые сервисы. Он\n                        показан отдельным сегментом в блоке Персональные сервисы. Б2Б Тех, включающий Yandex Cloud и Яндекс 360. Автономный транспорт, который вошел в новый сегмент Автономные\n                        технологии вместе с Яндекс Роботикс, ранее входившей в сегмент\n                        Электронная коммерция.'],
#  56)

# %%
METRICS = [
    "выручка", "рекламная выручка", "подписная выручка",
    "скорректированный показатель ebitda", "ebitda",
    "рентабельность", "скорректированная чистая прибыль", "чистая прибыль",
]

metric_re = re.compile("|".join([re.escape(m) for m in sorted(METRICS, key=len, reverse=True)]), re.I)

# "366,1 млрд рублей", "80 рублей на акцию"
money_re = re.compile(r"(\(?-?\d[\d\s]*[.,]?\d*\)?)\s*(млрд|млн|тыс)?\s*(руб(лей|ля|\.|)|₽)?", re.I)

def extract_facts_from_line(line: str):
    line_clean = line.lstrip("•* ").strip()
    doc = nlp(line_clean)

    # entity: ORG проверка
    orgs = [ent.text for ent in doc.ents if ent.label_ == "ORG"]
    entity = orgs[0] if orgs else "Яндекс"

    metric_m = metric_re.search(line_clean)
    metric = metric_m.group(0) if metric_m else None

    m = money_re.search(line_clean)
    value_raw = m.group(0).strip() if m else None
    value = normalize_value(m.group(1)) if m else None

    # период: "за третий квартал" / "за девять месяцев"
    period = None
    if re.search(r"трет(ий|ьего)\s+квартал", line_clean, re.I):
        period = "Q3 2025"
    if re.search(r"девят(ь|и)\s+месяц", line_clean, re.I):
        period = "9M 2025"

    return {
        "entity": entity,
        "metric": metric,
        "period": period,
        "value_raw": value_raw,
        "value": value,
        "source": "text_bullets",
        "context": line_clean
    }

text_facts = [extract_facts_from_line(ln) for ln in bullet_lines]
text_facts_df = pd.DataFrame([f for f in text_facts if f["metric"] and f["value_raw"]])

text_facts_df
# Out:
#                   entity                               metric   period  \
# 0                 Яндекс                              Выручка  Q3 2025
# 1                 Яндекс  Скорректированный показатель EBITDA  Q3 2025
# 2                 Яндекс                    Рекламная выручка  9M 2025
# 3                 Яндекс                    Подписная выручка  9M 2025
# 4  Электронной коммерции                    Рекламная выручка     None
# 5           Yandex Cloud                              выручка  9M 2025
# 6           Yandex Cloud                              Выручка     None
# 7          Яндекс 360 24                              выручка     None
#
#                            value_raw    value        source  \
# 0                  366,1 млрд рублей    366.1  text_bullets
# 1  78,1 млрд\n                рублей     78.1  text_bullets
# 2                                 11     11.0  text_bullets
# 3                                 48     48.0  text_bullets
# 4  15,5\n                млрд рублей     15.5  text_bullets
# 5                               2025   2025.0  text_bullets
# 6                               2025   2025.0  text_bullets
# 7                             360 24  36024.0  text_bullets
#
#                                              context
# 0  Выручка за третий квартал составила 366,1 млрд...
# 1  Скорректированный показатель EBITDA за третий ...
# 2  Рекламная выручка Яндекса выросла на 11% до 11...
# 3  Подписная выручка Яндекса выросла на 48% до 23...
# 4  Рекламная выручка Городских сервисов в третьем...
# 5  За девять месяцев 2025 года выручка ИИ-сервисо...
# 6  В третьем квартале 2025 года сервисами безопас...
# 7  Сервисами Яндекс 360 24 пользуются более 160 т...

# %%
table_facts = facts_clean.copy()
table_facts["period"] = table_facts["col"].astype(str)
table_facts["context"] = None

final_df = pd.concat(
    [
        table_facts[["entity","metric","period","value_raw","value","source"]],
        text_facts_df[["entity","metric","period","value_raw","value","source"]],
    ],
    ignore_index=True
)

final_df.head(30)
# Out:
#                          entity  \
# 0                   В млрд руб.
# 1                           NaN
# 2     Результаты Группы Яндекса
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6        Поисковые сервисы и ИИ
# 7                           NaN
# 8                           NaN
# 9             Городские сервисы
# 10                          NaN
# 11                          NaN
# 12         Персональные сервисы
# 13                          NaN
# 14                          NaN
# 15                      Б2Б Тех
# 16                          NaN
# 17                          NaN
# 18        Автономные технологии
# 19                          NaN
# 20  Прочие сервисы и инициативы
# 21                          NaN
# 22                     Персонал
# 23                          NaN
# 24                  В млрд руб.
# 25                          NaN
# 26    Результаты Группы Яндекса
# 27                          NaN
# 28                          NaN
# 29                          NaN
#
#                                                metric period  \
# 0                                                 NaN      2
# 1                                                 NaN      2
# 2                                             Выручка      2
# 3                 Скорректированный показатель EBITDA      2
# 4   Рентабельность скорректированного показателя E...      2
# 5                    Скорректированная чистая прибыль      2
# 6                                             Выручка      2
# 7                 Скорректированный показатель EBITDA      2
# 8   Рентабельность скорректированного показателя E...      2
# 9                                             Выручка      2
# 10                Скорректированный показатель EBITDA      2
# 11  Рентабельность скорректированного показателя E...      2
# 12                                            Выручка      2
# 13                Скорректированный показатель EBITDA      2
# 14  Рентабельность скорректированного показателя E...      2
# 15                                            Выручка      2
# 16                Скорректированный показатель EBITDA      2
# 17  Рентабельность скорректированного показателя E...      2
# 18                                            Выручка      2
# 19                Скорректированный показатель EBITDA      2
# 20                                            Выручка      2
# 21                Скорректированный показатель EBITDA      2
# 22               Численность основного персонала, чел      2
# 23                   Общая численность персонала, чел      2
# 24                                                NaN      3
# 25                                                NaN      3
# 26                                            Выручка      3
# 27                Скорректированный показатель EBITDA      3
# 28  Рентабельность скорректированного показателя E...      3
# 29                   Скорректированная чистая прибыль      3
#
#                                 value_raw    value   source
# 0   Три месяца, закончившиеся 30 сентября      0.3  table_0
# 1                                    2025   2025.0  table_0
# 2                                   366.1    366.1  table_0
# 3                                    78.1     78.1  table_0
# 4                                   21,3%     21.3  table_0
# 5                                    44.7     44.7  table_0
# 6                                   138.5    138.5  table_0
# 7                                    63.0     63.0  table_0
# 8                                   45,5%     45.5  table_0
# 9                                   200.4    200.4  table_0
# 10                                   18.9     18.9  table_0
# 11                                   9,4%      9.4  table_0
# 12                                   54.8     54.8  table_0
# 13                                    3.4      3.4  table_0
# 14                                   6,2%      6.2  table_0
# 15                                   12.4     12.4  table_0
# 16                                    2.2      2.2  table_0
# 17                                  17,4%     17.4  table_0
# 18                                    0.2      0.2  table_0
# 19                                  (4,2)     -4.2  table_0
# 20                                    2.7      2.7  table_0
# 21                                  (4,2)     -4.2  table_0
# 22                                  31188  31188.0  table_0
# 23                                  95097  95097.0  table_0
# 24  Три месяца, закончившиеся 30 сентября      0.3  table_0
# 25                                   2024   2024.0  table_0
# 26                                  276.8    276.8  table_0
# 27                                   54.7     54.7  table_0
# 28                                  19,8%     19.8  table_0
# 29                                   25.1     25.1  table_0

# %%
final_df.tail(30)
# Out:
#                           entity  \
# 122    Результаты Группы Яндекса
# 123                          NaN
# 124                          NaN
# 125                          NaN
# 126       Поисковые сервисы и ИИ
# 127                          NaN
# 128                          NaN
# 129            Городские сервисы
# 130                          NaN
# 131                          NaN
# 132         Персональные сервисы
# 133                          NaN
# 134                          NaN
# 135                      Б2Б Тех
# 136                          NaN
# 137                          NaN
# 138        Автономные технологии
# 139                          NaN
# 140  Прочие сервисы и инициативы
# 141                          NaN
# 142                     Персонал
# 143                          NaN
# 144                       Яндекс
# 145                       Яндекс
# 146                       Яндекс
# 147                       Яндекс
# 148        Электронной коммерции
# 149                 Yandex Cloud
# 150                 Yandex Cloud
# 151                Яндекс 360 24
#
#                                                 metric   period  \
# 122                                            Выручка        7
# 123                Скорректированный показатель EBITDA        7
# 124  Рентабельность скорректированного показателя E...        7
# 125                   Скорректированная чистая прибыль        7
# 126                                            Выручка        7
# 127                Скорректированный показатель EBITDA        7
# 128  Рентабельность скорректированного показателя E...        7
# 129                                            Выручка        7
# 130                Скорректированный показатель EBITDA        7
# 131  Рентабельность скорректированного показателя E...        7
# 132                                            Выручка        7
# 133                Скорректированный показатель EBITDA        7
# 134  Рентабельность скорректированного показателя E...        7
# 135                                            Выручка        7
# 136                Скорректированный показатель EBITDA        7
# 137  Рентабельность скорректированного показателя E...        7
# 138                                            Выручка        7
# 139                Скорректированный показатель EBITDA        7
# 140                                            Выручка        7
# 141                Скорректированный показатель EBITDA        7
# 142               Численность основного персонала, чел        7
# 143                   Общая численность персонала, чел        7
# 144                                            Выручка  Q3 2025
# 145                Скорректированный показатель EBITDA  Q3 2025
# 146                                  Рекламная выручка  9M 2025
# 147                                  Подписная выручка  9M 2025
# 148                                  Рекламная выручка     None
# 149                                            выручка  9M 2025
# 150                                            Выручка     None
# 151                                            выручка     None
#
#                              value_raw    value        source
# 122                                33%     33.0       table_0
# 123                                38%     38.0       table_0
# 124                           0,7 п.п.      NaN       table_0
# 125                                26%     26.0       table_0
# 126                                13%     13.0       table_0
# 127                                17%     17.0       table_0
# 128                           1,4 п.п.      NaN       table_0
# 129                                39%     39.0       table_0
# 130                               152%    152.0       table_0
# 131                           3,2 п.п.      NaN       table_0
# 132                                72%     72.0       table_0
# 133                             н/прим      NaN       table_0
# 134                             н/прим      NaN       table_0
# 135                                51%     51.0       table_0
# 136                               169%    169.0       table_0
# 137                           8,4 п.п.      NaN       table_0
# 138                               308%    308.0       table_0
# 139                                93%     93.0       table_0
# 140                                10%     10.0       table_0
# 141                                 7%      7.0       table_0
# 142                                11%     11.0       table_0
# 143                                 5%      5.0       table_0
# 144                  366,1 млрд рублей    366.1  text_bullets
# 145  78,1 млрд\n                рублей     78.1  text_bullets
# 146                                 11     11.0  text_bullets
# 147                                 48     48.0  text_bullets
# 148  15,5\n                млрд рублей     15.5  text_bullets
# 149                               2025   2025.0  text_bullets
# 150                               2025   2025.0  text_bullets
# 151                             360 24  36024.0  text_bullets
